# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('master_conservation_projects_database.csv',encoding='mac_roman')

# %%
data['Project Size (hectares)'].fillna('10,000', inplace=True)

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
# import module
from geopy.geocoders import Nominatim
  
# initialize Nominatim API
geolocator = Nominatim(user_agent="geoapiExercises")
  
# Latitude & Longitude input
Latitude = "2.269494556"
Longitude = "-72.75852614"
  
location = geolocator.reverse(Latitude+","+Longitude)
  
address = location.raw['address']
  
# traverse the data
city = address.get('city', '')
state = address.get('state', '')
country = address.get('country', '')
code = address.get('country_code')
zipcode = address.get('postcode')
print('City : ', city)
print('State : ', state)
print('Country : ', country)
print('Zip Code : ', zipcode)
# Out:
# City :
# State :  Guaviare
# Country :  Colombia
# Zip Code :  None

# %%
def set_state(x):
    
    if str(x['Project State']) == 'nan':
        
        Latitude = str(x['Latitude'])
        Longitude = str(x['Longitude'])

        location = geolocator.reverse(Latitude+","+Longitude)

        if "state" in location.raw['address'].keys():
            state = location.raw['address']['state']
            
        elif "region" in location.raw['address'].keys():
            state = location.raw['address']['region']
        
        elif "territory" in location.raw['address'].keys():
            state = location.raw['address']['territory']
        
        else:    
            return np.nan

        # just the american ones have the abbreviation
        if state in us_state_abbrev:
            return us_state_abbrev[state]
        else:
            return state
    
    else:
        return x['Project State']

# %%
def set_city(x):
    
    if str(x['Project City']).lower() == 'nan':
        
        Latitude = str(x['Latitude'])
        Longitude = str(x['Longitude'])

        location = geolocator.reverse(Latitude+","+Longitude)

        # there are several combinations
        
        if "town" in location.raw['address'].keys():
            return location.raw['address']['town']
        
        elif "city" in location.raw['address'].keys():
            return location.raw['address']['city']
        
        elif "county" in location.raw['address'].keys():
            return location.raw['address']['county']
        
        elif "village" in location.raw['address'].keys():
            return location.raw['address']['village']
        
        elif "suburb" in location.raw['address'].keys():
            return location.raw['address']['suburb']
        
        elif "state_district" in location.raw['address'].keys():
            return location.raw['address']['state_district']
        
        else:
            return np.nan
    
    else:
        return x['Project City']

# %%
df_cleaned = data.copy()
df_cleaned['Project State'] = data.apply(lambda x : set_state(x), axis=1)
df_cleaned['Project City'] = data.apply(lambda x : set_city(x), axis=1)

# %%
df_cleaned.at[21,'Project City'] = "Samraong"
df_cleaned.at[34,'Project City'] = "Bengalon"
df_cleaned.at[83,'Project City'] = "Luwanda"

# %%
df_cleaned.isnull().sum()[['Project City','Project State']]
# Out:
# Project City     0
# Project State    0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Organization                  84 non-null     object
#  1   HQ                            84 non-null     object
#  2   Year Established              84 non-null     int64
#  3   Type of Organization          84 non-null     object
#  4   Size (AUM)                    84 non-null     object
#  5   AUM                           84 non-null     float64
#  6   Project Name                  84 non-null     object
#  7   Financial Asset Class         84 non-null     object
#  8   Natural Asset Class           84 non-null     object
#  9   Returns Profile (Target IRR)  84 non-null     object
#  10  Sustainability Profile        84 non-null     object
#  11  Project Size (hectares)       84 non-null     object
#  12  Tree Species                  65 non-null     object
#  13  Project City                  84 non-null     object
#  14  Project State                 84 non-null     object
#  15  Project Country               84 non-null     object
#  16  Latitude                      84 non-null     float64
#  17  Longitude                     84 non-null     float64
#  18  Project Description           84 non-null     object
#  19  Project Website               84 non-null     object
#  20  Contact                       83 non-null     object
#  21  Approved                      84 non-null     bool
# dtypes: bool(1), float64(3), int64(1), object(17)
# memory usage: 14.0+ KB

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\anaconda\lib\site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\anaconda\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\anaconda\lib\site-packages (from plotly) (1.15.0)

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.express as px

# %% [markdown]
# # Relations Of Different Columns Against 'Project Size (hectares)'

# %%
fig = px.histogram(data, x="Organization", y="Project Size (hectares)", marginal="rug",color ="HQ")
fig.show()
# Out:
# <div>                            <div id="4d1cbf4f-c0ff-4fb9-af20-7a68c312a63a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d1cbf4f-c0ff-4fb9-af20-7a68c312a63a")) {                    Plotly.newPlot(                        "4d1cbf4f-c0ff-4fb9-af20-7a68c312a63a",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=USA<br>Organization=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "USA", "marker": {"color": "#636efa"}, "name": "USA", "offsetgroup": "USA", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "The Conservation Fund", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "NatureVest"], "xaxis": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=USA<br>Organization=%{x}<extra></extra>", "jitter": 0, "legendgroup": "USA", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "USA", "offsetgroup": "USA", "showlegend": false, "type": "box", "x": ["Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "The Conservation Fund", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "NatureVest"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=Australia<br>Organization=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Australia", "marker": {"color": "#EF553B"}, "name": "Australia", "offsetgroup": "Australia", "orientation": "v", "showlegend" ...

# %%
fig = px.pie(data, values='Project Size (hectares)', names='Organization', title='Organization vs Project Size (hectares)')
fig.show()
# Out:
# <div>                            <div id="a25e400c-27a1-4999-affd-99d8b3ed1bf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a25e400c-27a1-4999-affd-99d8b3ed1bf8")) {                    Plotly.newPlot(                        "a25e400c-27a1-4999-affd-99d8b3ed1bf8",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Organization=%{label}<br>Project Size (hectares)=%{value}<extra></extra>", "labels": ["Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "The Conservation Fund", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "Tropical Landscapes Finance Facility", "Tropical Landscapes Finance Facility", "&Green Fund", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Green Climate Fund", "Eco.business Fund", "Eco.business Fund", "Eco.business Fund", "Mirova Natural Capital (prev. Althelia Climate Fund)", "Mirova Natural Capital (prev. Althelia Climate Fund)", "Arbaro Fund", "Arbaro Fund", "Arbaro Fund", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "NatureVest", "World Bank Climate Pilot Aucation Facility (PAF)", "World Bank Climate Pilot Aucation Facility (PAF)", "Conservation Capital", "Conservation Capital", "Conservation Capital", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6" ...

# %%
fig = px.histogram(data, x="Type of Organization", y="Project Size (hectares)", marginal="rug",color ="HQ")
fig.show()
# Out:
# <div>                            <div id="740f2f55-945d-4387-9dc5-3b1d6b589d25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("740f2f55-945d-4387-9dc5-3b1d6b589d25")) {                    Plotly.newPlot(                        "740f2f55-945d-4387-9dc5-3b1d6b589d25",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=USA<br>Type of Organization=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "USA", "marker": {"color": "#636efa"}, "name": "USA", "offsetgroup": "USA", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "In-house Impact Investment Team at The Nature Conservancy"], "xaxis": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=USA<br>Type of Organization=%{x}<extra></extra>", "jitter": 0, "legendgroup": "USA", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "USA", "offsetgroup": "USA", "showlegend": false, "type": "box", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "In-house Impact Investment Team at The Nature Conservancy"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=Australia<br>Type of Organization=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Australia", "marker": {"color": "#EF553B"}, "name": "Australia", "offsetgroup": "Australia", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO"], "xaxis": "x", "y": ["10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=Australia<br>Type of Organization=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Australia", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Australia", "offsetgroup": "Australia", "showlegend": false, "type": "box", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO"], "xaxis": "x2", "yaxis": "y2"}, {"ali ...

# %%
fig = px.histogram(data, x="Type of Organization", y="Project Size (hectares)", marginal="rug",color ="Project Country")
fig.show()
# Out:
# <div>                            <div id="0b2a984b-4311-40d5-9aac-fa8e36b24091" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b2a984b-4311-40d5-9aac-fa8e36b24091")) {                    Plotly.newPlot(                        "0b2a984b-4311-40d5-9aac-fa8e36b24091",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Project Country=USA<br>Type of Organization=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "USA", "marker": {"color": "#636efa"}, "name": "USA", "offsetgroup": "USA", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "In-house Impact Investment Team at The Nature Conservancy"], "xaxis": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Project Country=USA<br>Type of Organization=%{x}<extra></extra>", "jitter": 0, "legendgroup": "USA", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "USA", "offsetgroup": "USA", "showlegend": false, "type": "box", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "In-house Impact Investment Team at The Nature Conservancy"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Project Country=Indonesia<br>Type of Organization=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Indonesia", "marker": {"color": "#EF553B"}, "name": "Indonesia", "offsetgroup": "Indonesia", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Private Sector Financing", "Private Sector Financing", "Investment Fund", "Investors/ Asset Managers"], "xaxis": "x", "y": ["70,000", "18,000", "93,000", "22,934"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Project Country=Indonesia<br>Type of Organization=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Indonesia", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Indonesia", "offsetgroup": "Indonesia", "showlegend": false, "type": "box", "x": ["Private Sector Financing", "Private Sector Financi ...

# %%
fig = px.pie(data, values='Project Size (hectares)', names='Financial Asset Class', title='Project Size (hectares) vs Financial Asset Class')
fig.show()
# Out:
# <div>                            <div id="ccd5c33a-ef7c-4d6a-bc05-905659bbc924" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccd5c33a-ef7c-4d6a-bc05-905659bbc924")) {                    Plotly.newPlot(                        "ccd5c33a-ef7c-4d6a-bc05-905659bbc924",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Financial Asset Class=%{label}<br>Project Size (hectares)=%{value}<extra></extra>", "labels": ["Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Notes", "Commodities", "Loan", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Loan & Grant", "Loan", "Loan", "Loan", "Loan", "Loan", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Debt, Equity", "Options", "Options", "Conservation Bonds", "Conservation Bonds", "Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3 ...

# %%
fig = px.pie(data, values='Project Size (hectares)', names='Natural Asset Class', title='Project Size (hectares) vs Natural Asset Class')
fig.show()
# Out:
# <div>                            <div id="7e39f095-e969-4a49-931a-7ed7211c3f5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e39f095-e969-4a49-931a-7ed7211c3f5b")) {                    Plotly.newPlot(                        "7e39f095-e969-4a49-931a-7ed7211c3f5b",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Natural Asset Class=%{label}<br>Project Size (hectares)=%{value}<extra></extra>", "labels": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest", "Agroforestry", "Agroforestry", "Wetlands", "Forest (Riparian) ", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest", "Forest (Riparian) ", "Forest", "Forest", "Wetlands", "Forest ", "Wetlands", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]],  ...

# %%
fig = px.pie(data, values='Project Size (hectares)', names='Project State', title='Project Size (hectares) vs Project State')
fig.show()
# Out:
# <div>                            <div id="3f0e31fa-151f-4596-8b51-e12dfea54d1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f0e31fa-151f-4596-8b51-e12dfea54d1d")) {                    Plotly.newPlot(                        "3f0e31fa-151f-4596-8b51-e12dfea54d1d",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Project State=%{label}<br>Project Size (hectares)=%{value}<extra></extra>", "labels": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Jambi", "East Kalimantan", "East Kalimantan", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland", null, "Cotopaxi", "Upala", "Ahuachapan Province", "South Sumatra", "Izabal", "Yoni", "Ashanti Region", "San Estanisalo", "Limpopo", "Western Cape, Eastern Cape, Mpumalanga", "Eastern Cape", "Mpumalanga", "Morogoro", "Piggs Peak", "Sabie", "Mpumalanga", null, "WA", "WA", "WA", "WA", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "CA", "VA, KY, TN", null, null, null, null, null, null, null, null, null, null, null, null, null], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777777777777 ...

# %%
fig = px.histogram(data, x="Returns Profile (Target IRR)", y="Project Size (hectares)", marginal="rug",color ="Organization")
fig.show()
# Out:
# <div>                            <div id="8238a851-ea2c-4ab6-b12d-c329b88a80b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8238a851-ea2c-4ab6-b12d-c329b88a80b1")) {                    Plotly.newPlot(                        "8238a851-ea2c-4ab6-b12d-c329b88a80b1",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Ecosystem Investment Partners (EIP)", "marker": {"color": "#636efa"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["5-9.9%", "5-9.9%", "5-9.9%"], "xaxis": "x", "y": ["10,000", "405", "4,046 per year"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Ecosystem Investment Partners (EIP)", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "showlegend": false, "type": "box", "x": ["5-9.9%", "5-9.9%", "5-9.9%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Lyme Forest Fund<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Lyme Forest Fund", "marker": {"color": "#EF553B"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%"], "xaxis": "x", "y": ["273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Lyme Forest Fund<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Lyme Forest Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "showlegend": false, "type": "box", "x": ["22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=The Conservation Fund<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "The Conservation Fund", "marker": {"color": "#00cc96"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10-14.9%"], "xaxis": "x", "y": ["29947"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=The Conservation Fund<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "The Conservation Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line-ns-open"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "showlegend": false, "type": "box", "x": ["10-14.9%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=New Forests<br>Returns Profile (Target IRR)=%{x}<br>su ...

# %%
fig = px.histogram(data, x="Returns Profile (Target IRR)", y="Project Size (hectares)", marginal="rug",color ="Type of Organization")
fig.show()
# Out:
# <div>                            <div id="cc18f9aa-6177-4dc3-8371-ad84b4893008" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc18f9aa-6177-4dc3-8371-ad84b4893008")) {                    Plotly.newPlot(                        "cc18f9aa-6177-4dc3-8371-ad84b4893008",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=TIMO<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "TIMO", "marker": {"color": "#636efa"}, "name": "TIMO", "offsetgroup": "TIMO", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%"], "xaxis": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=TIMO<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "TIMO", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "TIMO", "offsetgroup": "TIMO", "showlegend": false, "type": "box", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Nonprofit<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Nonprofit", "marker": {"color": "#EF553B"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10-14.9%"], "xaxis": "x", "y": ["29947"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Nonprofit<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Nonprofit", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "showlegend": false, "type": "box", "x": ["10-14.9%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Private Sector Financing<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Private Sector Financing", "marker": {"color": "#00cc96"}, "name": "Private Sector Financing", "offsetgroup": "Private Sector Financing", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10-20%", "10-20%"], "xaxis": "x", "y": ["70,000", "18,000"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Private Sector Financing<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Private Sector Financing", "li ...

# %%
fig = px.histogram(data, x="Returns Profile (Target IRR)", y="Project Size (hectares)", marginal="rug",color ="Project Country")
fig.show()
# Out:
# <div>                            <div id="3005712b-886a-44b3-8772-3e61d366b41a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3005712b-886a-44b3-8772-3e61d366b41a")) {                    Plotly.newPlot(                        "3005712b-886a-44b3-8772-3e61d366b41a",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Project Country=USA<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "USA", "marker": {"color": "#636efa"}, "name": "USA", "offsetgroup": "USA", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%"], "xaxis": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Project Country=USA<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "USA", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "USA", "offsetgroup": "USA", "showlegend": false, "type": "box", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Project Country=Indonesia<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Indonesia", "marker": {"color": "#EF553B"}, "name": "Indonesia", "offsetgroup": "Indonesia", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10-20%", "10-20%", ">10%", "8%"], "xaxis": "x", "y": ["70,000", "18,000", "93,000", "22,934"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Project Country=Indonesia<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Indonesia", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Indonesia", "offsetgroup": "Indonesia", "showlegend": false, "type": "box", "x": ["10-20%", "10-20%", ">10%", "8%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Project Country=Brazil<br>Returns Profile (Target IRR)=%{x}<br>sum of Project Size (hectares)=%{y}<extra></extra>", "legendgroup": "Brazil", "marker": {"color": "#00cc96"}, "name": "Brazil", "offsetgroup": "Brazil", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["9.80%", "9.80%", "9.80%", "9.80%", "9-10%"], "xaxis": "x", "y": ["36,372", "12,594", "36,372", "12,594", "170,500"], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Project Country=Brazil<br>Returns Profile (Target IRR)=%{x}<extra></extra> ...

# %%
fig = px.density_heatmap(data, x="Returns Profile (Target IRR)", y="Project Size (hectares)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="66f8ee08-f122-45b1-8aec-2415f2b97ee3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66f8ee08-f122-45b1-8aec-2415f2b97ee3")) {                    Plotly.newPlot(                        "66f8ee08-f122-45b1-8aec-2415f2b97ee3",                        [{"coloraxis": "coloraxis", "hovertemplate": "Returns Profile (Target IRR)=%{x}<br>Project Size (hectares)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "xaxis": "x", "xbingroup": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Returns Profile (Target IRR)=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "xaxis": "x3", "yaxis": "y3"}, {"alignmentgroup": "True", "bingroup": "y", "hovertemplate": "Project Size (hectares)=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "xaxi ...

# %%
fig = px.density_heatmap(data, x="Financial Asset Class", y="Project Size (hectares)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="175e8a7a-fe35-4c61-a029-6ed3ba75b9ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("175e8a7a-fe35-4c61-a029-6ed3ba75b9ee")) {                    Plotly.newPlot(                        "175e8a7a-fe35-4c61-a029-6ed3ba75b9ee",                        [{"coloraxis": "coloraxis", "hovertemplate": "Financial Asset Class=%{x}<br>Project Size (hectares)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Notes", "Commodities", "Loan", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Loan & Grant", "Loan", "Loan", "Loan", "Loan", "Loan", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Debt, Equity", "Options", "Options", "Conservation Bonds", "Conservation Bonds", "Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan"], "xaxis": "x", "xbingroup": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Financial Asset Class=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Notes", "Commodities", "Loan", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Loan & Grant", "Loan", "Loan", "Loan" ...

# %%
fig = px.density_heatmap(data, x="Natural Asset Class", y="Project Size (hectares)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="38130aaa-d21f-4aaa-bad1-1711432018bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38130aaa-d21f-4aaa-bad1-1711432018bf")) {                    Plotly.newPlot(                        "38130aaa-d21f-4aaa-bad1-1711432018bf",                        [{"coloraxis": "coloraxis", "hovertemplate": "Natural Asset Class=%{x}<br>Project Size (hectares)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest", "Agroforestry", "Agroforestry", "Wetlands", "Forest (Riparian) ", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest", "Forest (Riparian) ", "Forest", "Forest", "Wetlands", "Forest ", "Wetlands", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest"], "xaxis": "x", "xbingroup": "x", "y": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Natural Asset Class=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest", "Agroforestry", "Agroforestry", "Wetlands", "Forest (Riparian) ", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest (Riparian) ", "Forest (R ...

# %%
fig = px.pie(data, values='Project Size (hectares)', names='Year Established', title='Project Size (hectares) vs Year Established')
fig.show()
# Out:
# <div>                            <div id="46aaad26-47b1-4156-980e-7ed149f5b8d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46aaad26-47b1-4156-980e-7ed149f5b8d1")) {                    Plotly.newPlot(                        "46aaad26-47b1-4156-980e-7ed149f5b8d1",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Year Established=%{label}<br>Project Size (hectares)=%{value}<extra></extra>", "labels": [2006, 2006, 2007, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 1985, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2016, 2016, 2017, 2007, 2007, 2007, 2007, 2007, 2007, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 2010, 2014, 2014, 2014, 2012, 2012, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2014, 2015, 2015, 2004, 2004, 2004, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0. ...

# %% [markdown]
# # Relations Of Different Columns Against 'Returns Profile (Target IRR)'

# %%
fig = px.pie(data, values='Year Established', names='Returns Profile (Target IRR)', title='Year Established vs Returns Profile (Target IRR)')
fig.show()
# Out:
# <div>                            <div id="e06fb1ba-0f40-4f81-a505-3253099e5c18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e06fb1ba-0f40-4f81-a505-3253099e5c18")) {                    Plotly.newPlot(                        "e06fb1ba-0f40-4f81-a505-3253099e5c18",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Returns Profile (Target IRR)=%{label}<br>Year Established=%{value}<extra></extra>", "labels": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [2006, 2006, 2007, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 1985, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2016, 2016, 2017, 2007, 2007, 2007, 2007, 2007, 2007, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 2010, 2014, 2014, 2014, 2012, 2012, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2014, 2015, 2015, 2004, 2004, 2004, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.66666666666666 ...

# %%
fig = px.density_heatmap(data, x="Organization", y="Returns Profile (Target IRR)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="b7d4b0be-7cf1-4ba3-89db-ec35bf8ecf30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7d4b0be-7cf1-4ba3-89db-ec35bf8ecf30")) {                    Plotly.newPlot(                        "b7d4b0be-7cf1-4ba3-89db-ec35bf8ecf30",                        [{"coloraxis": "coloraxis", "hovertemplate": "Organization=%{x}<br>Returns Profile (Target IRR)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "The Conservation Fund", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "Tropical Landscapes Finance Facility", "Tropical Landscapes Finance Facility", "&Green Fund", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Green Climate Fund", "Eco.business Fund", "Eco.business Fund", "Eco.business Fund", "Mirova Natural Capital (prev. Althelia Climate Fund)", "Mirova Natural Capital (prev. Althelia Climate Fund)", "Arbaro Fund", "Arbaro Fund", "Arbaro Fund", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "NatureVest", "World Bank Climate Pilot Aucation Facility (PAF)", "World Bank Climate Pilot Aucation Facility (PAF)", "Conservation Capital", "Conservation Capital", "Conservation Capital", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100"], "xaxis": "x", "xbingroup": "x", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Organization=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["Ecosy ...

# %%
fig = px.density_heatmap(data, x="Type of Organization", y="Returns Profile (Target IRR)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="095ac9e7-2896-454e-bd9e-23998be9c406" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("095ac9e7-2896-454e-bd9e-23998be9c406")) {                    Plotly.newPlot(                        "095ac9e7-2896-454e-bd9e-23998be9c406",                        [{"coloraxis": "coloraxis", "hovertemplate": "Type of Organization=%{x}<br>Returns Profile (Target IRR)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Sector Financing", "Private Sector Financing", "Investment Fund", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Equity Fund", "Impact Investment Fund", "Impact Investment Fund", "Impact Investment Fund", "Investors/ Asset Managers", "Investors/ Asset Managers", "Private Equity Fund", "Private Equity Fund", "Private Equity Fund", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "In-house Impact Investment Team at The Nature Conservancy", "DFI", "DFI", "Impact Driven Company", "Impact Driven Company", "Impact Driven Company", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund"], "xaxis": "x", "xbingroup": "x", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Type of Organization=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Sector Financing", "Private Sector Financing", "Investment Fund", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Equity Fund", "Impact Investment Fund", "Impact Investment Fund", "Impact Investment Fund", "Investors/ Asset Managers", "Investors/ Asset Managers", "Private Equity Fund", "Private Equi ...

# %%
fig = px.density_heatmap(data, x="Financial Asset Class", y="Returns Profile (Target IRR)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="c90f55f9-5720-4930-ba85-00b435a128e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c90f55f9-5720-4930-ba85-00b435a128e7")) {                    Plotly.newPlot(                        "c90f55f9-5720-4930-ba85-00b435a128e7",                        [{"coloraxis": "coloraxis", "hovertemplate": "Financial Asset Class=%{x}<br>Returns Profile (Target IRR)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Notes", "Commodities", "Loan", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Loan & Grant", "Loan", "Loan", "Loan", "Loan", "Loan", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Debt, Equity", "Options", "Options", "Conservation Bonds", "Conservation Bonds", "Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan", "Equity, Grant, Loan"], "xaxis": "x", "xbingroup": "x", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Financial Asset Class=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Notes", "Commodities", "Loan", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Loan & Grant", "Loan", "Loan", "Loan", "Loan", "Loan", "Commodities", "Commodities", "Commodities", "Commodities", "C ...

# %%
fig = px.density_heatmap(data, x="Natural Asset Class", y="Returns Profile (Target IRR)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="910c9c20-7bce-4b9a-95fc-4b0b59e257d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("910c9c20-7bce-4b9a-95fc-4b0b59e257d6")) {                    Plotly.newPlot(                        "910c9c20-7bce-4b9a-95fc-4b0b59e257d6",                        [{"coloraxis": "coloraxis", "hovertemplate": "Natural Asset Class=%{x}<br>Returns Profile (Target IRR)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest", "Agroforestry", "Agroforestry", "Wetlands", "Forest (Riparian) ", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest", "Forest (Riparian) ", "Forest", "Forest", "Wetlands", "Forest ", "Wetlands", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest"], "xaxis": "x", "xbingroup": "x", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Natural Asset Class=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest", "Agroforestry", "Agroforestry", "Wetlands", "Forest (Riparian) ", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Rip ...

# %%
fig = px.density_heatmap(data, x="Project Country", y="Returns Profile (Target IRR)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="71089bdb-615c-49b3-8d2b-3b7ad80b6aa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71089bdb-615c-49b3-8d2b-3b7ad80b6aa4")) {                    Plotly.newPlot(                        "71089bdb-615c-49b3-8d2b-3b7ad80b6aa4",                        [{"coloraxis": "coloraxis", "hovertemplate": "Project Country=%{x}<br>Returns Profile (Target IRR)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Indonesia", "Indonesia", "Indonesia", "Brazil", "Brazil", "Brazil", "Brazil", "Colombia", "Colombia", "Brazil", "Uruguay", "Chile", "Colombia", "Guatemala", "Cambodia", "Australia", "New Zealand", "Paraguay", "Ecuador", "Costa Rica", "El Salvador", "Indonesia", "Guatemala", "Sierra Leone", "Ghana", "Paraguay", "South Africa", "South Africa", "South Africa", "South Africa", "Tanzania", "Swaziland", "South Africa", "South Africa", "Gabon", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Guatemala", "Guatemala", "Pan-African", "Pan-African", "Portugal", "Ethiopia", "Nigeria", "Senegal", "Tanzania", "Rwanda", "Niger", "Mozambique", "Malawi"], "xaxis": "x", "xbingroup": "x", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Project Country=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Indonesia", "Indonesia", "Indonesia", "Brazil", "Brazil", "Brazil", "Brazil", "Colombia", "Colombia", "Brazil", "Uruguay", "Chile", "Colombia", "Guatemala", "Cambodia", "Australia", "New Zealand", "Paraguay", "Ecuador", "Costa Rica", "El Salvador", "Indonesia", "Guatemala", "Sierra Leone", "Ghana", "Paraguay", "South Africa", "South Africa", "South Africa", "South Africa", "Tanzania", "Swaziland", "South Africa", "South Africa", "Gabon", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Guatemala", "Guatemala", "Pan-African", "Pan-African", "Portugal", "Ethiopia", "Nigeria", "Senegal", "Tanzania", "Rwanda", "Niger", "Mozambique", "Malawi"], "xaxis": "x3", "yaxis": "y3"}, {"alignmentgroup": "True", "bingroup": "y", "hovertemplate": "Returns Profile (Target IRR)=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "xaxis": "x2", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", ...

# %%
fig = px.density_heatmap(data, x="Project State", y="Returns Profile (Target IRR)", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="a4fae99a-ed66-4396-8a97-451faeee07df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4fae99a-ed66-4396-8a97-451faeee07df")) {                    Plotly.newPlot(                        "a4fae99a-ed66-4396-8a97-451faeee07df",                        [{"coloraxis": "coloraxis", "hovertemplate": "Project State=%{x}<br>Returns Profile (Target IRR)=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Jambi", "East Kalimantan", "East Kalimantan", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland", null, "Cotopaxi", "Upala", "Ahuachapan Province", "South Sumatra", "Izabal", "Yoni", "Ashanti Region", "San Estanisalo", "Limpopo", "Western Cape, Eastern Cape, Mpumalanga", "Eastern Cape", "Mpumalanga", "Morogoro", "Piggs Peak", "Sabie", "Mpumalanga", null, "WA", "WA", "WA", "WA", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "CA", "VA, KY, TN", null, null, null, null, null, null, null, null, null, null, null, null, null], "xaxis": "x", "xbingroup": "x", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Project State=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Jambi", "East Kalimantan", "East Kalimantan", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland", null, "Cotopaxi", "Upala", "Ahuachapan Province", "South Sumatra", "Izabal", "Yoni", "Ashanti Region", "San Estanisalo", "Limpopo", "Western Cape, Eastern Cape, Mpumalanga", "Eastern Cape", "Mpumalanga", "Morogoro", "Piggs Peak", "Sabie", "Mpumalanga", null, "WA", "WA", "WA", "WA", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "CA", "VA, KY, TN", null, null, null, null, null, null, null, null, null, null, null, null, null], "xaxis": "x3", "yaxis": "y3"}, {"alignmentgroup": "True", "bingroup": "y", "hovertemplate": "Returns Profile (Target IRR)=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "xaxis": "x2", "y": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80% ...

# %%
fig = px.pie(data, values='Project Size (hectares)', names='Returns Profile (Target IRR)', title='Project Size (hectares) vs Returns Profile (Target IRR)')
fig.show()
# Out:
# <div>                            <div id="06ab41fe-a6d6-4537-a2fc-5d2e4fc9e204" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06ab41fe-a6d6-4537-a2fc-5d2e4fc9e204")) {                    Plotly.newPlot(                        "06ab41fe-a6d6-4537-a2fc-5d2e4fc9e204",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Returns Profile (Target IRR)=%{label}<br>Project Size (hectares)=%{value}<extra></extra>", "labels": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "70,000", "18,000", "93,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "24,000", "17,655", "2,400", "255", "22,934", "2,406", "10,000", "10,000", "2,658", "6,400", "57,100", "57,100", "57,100", "28,000", "31,500", "8,300", "3,671", "568,543", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386", "10,000", "10,000", "10,000", "10,000", "3,900", "15 million (committed)", "4 million  (committed)", "2 million (committed)", "5.2 million (committed)", "2 million (committed)", "3.2 million (committed)", "1 million (committed)", "4.5 million (committed)"]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.55555 ...
