# %%
# !pip install pandas_visual_analysis
# Out:
# Collecting pandas_visual_analysis
#   Downloading pandas_visual_analysis-0.0.4-py3-none-any.whl (34 kB)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\anaconda\lib\site-packages (from pandas_visual_analysis) (7.5.1)
# Requirement already satisfied: pandas>=1.1.0 in c:\anaconda\lib\site-packages (from pandas_visual_analysis) (1.1.3)
# Requirement already satisfied: setuptools>=49.2.0 in c:\anaconda\lib\site-packages (from pandas_visual_analysis) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.19.1 in c:\anaconda\lib\site-packages (from pandas_visual_analysis) (1.19.2)
# Requirement already satisfied: plotly>=4.10.0 in c:\anaconda\lib\site-packages (from pandas_visual_analysis) (4.14.3)
# Collecting blinker>=1.4
#   Downloading blinker-1.4.tar.gz (111 kB)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (7.19.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.0.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2020.1)
# Requirement already satisfied: retrying>=1.3.3 in c:\anaconda\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (1.3.3)
# Requirement already satisfied: six in c:\anaconda\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (1.15.0)
# Requirement already satisfied: decorator in c:\anaconda\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (4.4.2)
# Requirement already satisfied: pickleshare in c:\anaconda\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\anaconda\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.8)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\anaconda\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4.4)
# Requirement already satisfied: backcall in c:\anaconda\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: pygments in c:\anaconda\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (2.7.2)
# Requirement already satisfied: jedi>=0.10 in c:\anaconda\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (0.17.1)
# Requirement already satisfied: ipython-genutils in c:\anaconda\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1.4)
# Requirement already satisfied: tornado>=4.2 in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.0.4)
# Requirement already satisfied: jupyter-client in c:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1.7)
# Requirement already satisfied: jupyter-core in c:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.2.0)
# Requirement already satisfied: wcwidth in c:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\anaconda\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.0)
# Requirement already satisfied: nbconvert in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (20.1.0)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.11.2)
# Requirement already satisfied: Send2Trash in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.9.1)
# Requirement already satisfied: pyzmq>=17 in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (19.0.2)
# Requirement already satisfied: prometheus-client in c:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\anaconda\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (227)
# Requirement already satisfied: attrs>=17.4.0 in c:\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.17.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: testpath in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4.4)
# Requirement already satisfied: bleach in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.2.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.4)
# Requirement already satisfied: defusedxml in c:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.6.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.14.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.1.1)
# Requirement already satisfied: pywinpty>=0.5 in c:\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.7)
# Requirement already satisfied: webencodings in c:\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.1)
# Requirement already satisfied: packaging in c:\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (20.4)
# Requirement already satisfied: async-generator in c:\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.10)
# Requirement already satisfied: nest-asyncio in c:\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.4.2)
# Requirement already satisfied: pycparser in c:\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\anaconda\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.4.7)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13454 sha256=bdd9f913637305e40ccc0071c5b21afdfc85e190dca8cf3a51ea96d8643409e1
#   Stored in directory: c:\users\nisarg mehta\appdata\local\pip\cache\wheels\b7\a5\68\fe632054a5eadd531c7a49d740c50eb6adfbeca822b4eab8d4
# Successfully built blinker
# Installing collected packages: blinker, pandas-visual-analysis
# Successfully installed blinker-1.4 pandas-visual-analysis-0.0.4

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("CaliforniaFireIncidents_Cleaned - CaliforniaFireIncidents_Cleaned.csv.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  AcresBurned                                          AdminUnit  \
# 0           0     257314.0  Stanislaus National Forest/Yosemite National Park
# 1           1      30274.0  USFS Angeles National Forest/Los Angeles Count...
# 2           2      27531.0  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3           3      27440.0                              Tahoe National Forest
# 4           4      24251.0                       Ventura County Fire/CAL FIRE
#
#    ArchiveYear  CalFireIncident     Counties CountyIds Extinguished  Featured  \
# 0         2013             True     Tuolumne        55   2013-09-06     False
# 1         2013             True  Los Angeles        19   2013-06-08     False
# 2         2013             True    Riverside        33   2013-07-30     False
# 3         2013            False       Placer        31   2013-08-30     False
# 4         2013             True      Ventura        56   2013-05-11     False
#
#    Final    Latitude                                           Location  \
# 0   True    51.17.00            3 miles east of Groveland along Hwy 120
# 1   True  9793.55.00                            Angeles National Forest
# 2   True   151.15.00              Hwy 243 & Hwy 74 near Mountain Center
# 3   True    39.12.00            Deadwood Ridge, northeast of Foresthill
# 4   True         0.0  Southbound Highway 101 at Camarillo Springs Ro...
#
#      Longitude  MajorIncident             Name  Public     Started     Status
# 0   -121.26.00          False         Rim Fire    True  2013-08-17  Finalized
# 1  -7170.56.00          False  Powerhouse Fire    True  2013-05-30  Finalized
# 2  -1330.45.00          False    Mountain Fire    True  2013-07-15  Finalized
# 3   -121.05.00          False    American Fire    True  2013-08-10  Finalized
# 4          0.0           True     Springs Fire    True  2013-05-02  Finalized

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
df.describe()
# Out:
#         Unnamed: 0    AcresBurned  ArchiveYear
# count  1636.000000    1636.000000  1636.000000
# mean    817.500000    4581.211491  2016.608802
# std     472.416836   27241.988777     1.845340
# min       0.000000       0.000000  2013.000000
# 25%     408.750000      35.000000  2015.000000
# 50%     817.500000     100.000000  2017.000000
# 75%    1226.250000     420.500000  2018.000000
# max    1635.000000  410203.000000  2019.000000

# %%
VisualAnalysis(df)
# Out:
# VBox(children=(ToggleButtons(_dom_classes=('layout-382b156201434947bd3b432b805695c3',), description='Selection…
